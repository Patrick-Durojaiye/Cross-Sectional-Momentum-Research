# %%
import pandas as pd
import os

# %%
input_dir = "../data/uncleaned/ohlcv"  
output_dir = "../data/cleaned/ohlcv" 
os.makedirs(output_dir, exist_ok=True)

# %%
for file_name in os.listdir(input_dir):
    if file_name.endswith('.csv'):  # Process only CSV files
        file_path = os.path.join(input_dir, file_name)
        
        # Load the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Ensure the necessary columns exist
        if {'open', 'high', 'low', 'close'}.issubset(df.columns):
            
            # Calculate the distances
            df['OH_dist'] = df['high'] - df['open']
            df['OL_dist'] = df['open'] - df['low']
            df['HL_dist'] = df['high'] - df['low']
            df['LC_dist'] = df['close'] - df['low']
            df['HC_dist'] = df['high'] - df['close']
            
            # Total distances
            df['OHLC_dist'] = df['OH_dist'] + df['HL_dist'] + df['LC_dist']
            df['OLHC_dist'] = df['OH_dist'] + df['HL_dist'] + df['HC_dist']
            
            # Calculate means
            df['OH_mean'] = (df['open'] + df['high']) / 2
            df['OL_mean'] = (df['open'] + df['low']) / 2
            df['HL_mean'] = (df['high'] + df['low']) / 2
            df['LC_mean'] = (df['low'] + df['close']) / 2
            df['HC_mean'] = (df['high'] + df['close']) / 2
            
            # Calculate TWAP components
            df['OHLC_twap'] = (
                (df['OH_dist'] / df['OHLC_dist']) * df['OH_mean'] +
                (df['HL_dist'] / df['OHLC_dist']) * df['HL_mean'] +
                (df['LC_dist'] / df['OHLC_dist']) * df['LC_mean']
            )
            
            df['OLHC_twap'] = (
                (df['OL_dist'] / df['OLHC_dist']) * df['OL_mean'] +
                (df['HL_dist'] / df['OLHC_dist']) * df['HL_mean'] +
                (df['HC_dist'] / df['OLHC_dist']) * df['HC_mean']
            )
            
            # Final TWAP
            df['TWAP'] = (df['OHLC_twap'] + df['OLHC_twap']) / 2
            
            df = df[['timestamp', 'open', 'high', 'low', 'close', 'volume', 'TWAP']]
            
            # Save the updated DataFrame to a new CSV file
            output_file_path = os.path.join(output_dir, file_name)
            df.to_csv(output_file_path, index=False)
            
            print(f"Processed {file_name} and saved to {output_file_path}")
        else:
            print(f"File {file_name} is missing required columns. Skipping.")

print("TWAP calculation completed for all files.")
# Out:
# Processed 1000000MOG_ohlcv.csv and saved to ../data/cleaned/ohlcv\1000000MOG_ohlcv.csv
# Processed 1000BONK_ohlcv.csv and saved to ../data/cleaned/ohlcv\1000BONK_ohlcv.csv
# Processed 1000BTT_ohlcv.csv and saved to ../data/cleaned/ohlcv\1000BTT_ohlcv.csv
# Processed 1000FLOKI_ohlcv.csv and saved to ../data/cleaned/ohlcv\1000FLOKI_ohlcv.csv
# Processed 1000LUNC_ohlcv.csv and saved to ../data/cleaned/ohlcv\1000LUNC_ohlcv.csv
# Processed 1000PEPE_ohlcv.csv and saved to ../data/cleaned/ohlcv\1000PEPE_ohlcv.csv
# Processed 1000SATS_ohlcv.csv and saved to ../data/cleaned/ohlcv\1000SATS_ohlcv.csv
# Processed 1000SHIB_ohlcv.csv and saved to ../data/cleaned/ohlcv\1000SHIB_ohlcv.csv
# Processed 1000XEC_ohlcv.csv and saved to ../data/cleaned/ohlcv\1000XEC_ohlcv.csv
# Processed 1INCH_ohlcv.csv and saved to ../data/cleaned/ohlcv\1INCH_ohlcv.csv
# Processed AAVE_ohlcv.csv and saved to ../data/cleaned/ohlcv\AAVE_ohlcv.csv
# Processed ADA_ohlcv.csv and saved to ../data/cleaned/ohlcv\ADA_ohlcv.csv
# Processed AERO_ohlcv.csv and saved to ../data/cleaned/ohlcv\AERO_ohlcv.csv
# Processed AEVO_ohlcv.csv and saved to ../data/cleaned/ohlcv\AEVO_ohlcv.csv
# Processed AGIX_ohlcv.csv and saved to ../data/cleaned/ohlcv\AGIX_ohlcv.csv
# Processed AIOZ_ohlcv.csv and saved to ../data/cleaned/ohlcv\AIOZ_ohlcv.csv
# Processed AKT_ohlcv.csv and saved to ../data/cleaned/ohlcv\AKT_ohlcv.csv
# Processed ALGO_ohlcv.csv and saved to ../data/cleaned/ohlcv\ALGO_ohlcv.csv
# Processed ALT_ohlcv.csv and saved to ../data/cleaned/ohlcv\ALT_ohlcv.csv
# Processed ANKR_ohlcv.csv and saved to ../data/cleaned/ohlcv\ANKR_ohlcv.csv
# Processed APE_ohlcv.csv and saved to ../data/cleaned/ohlcv\APE_ohlcv.csv
# Processed APT_ohlcv.csv and saved to ../data/cleaned/ohlcv\APT_ohlcv.csv
# Processed ARB_ohlcv.csv and saved to ../data/cleaned/ohlcv\ARB_ohlcv.csv
# Processed AR_ohlcv.csv and saved to ../data/cleaned/ohlcv\AR_ohlcv.csv
# Processed ASTR_ohlcv.csv and saved to ../data/cleaned/ohlcv\ASTR_ohlcv.csv
# Processed ATOM_ohlcv.csv and saved to ../data/cleaned/ohlcv\ATOM_ohlcv.csv
# Processed AUDIO_ohlcv.csv and saved to ../data/cleaned/ohlcv\AUDIO_ohlcv.csv
# Processed AVAX_ohlcv.csv and saved to ../data/cleaned/ohlcv\AVAX_ohlcv.csv
# Processed AXL_ohlcv.csv and saved to ../data/cleaned/ohlcv\AXL_ohlcv.csv
# Processed AXS_ohlcv.csv and saved to ../data/cleaned/ohlcv\AXS_ohlcv.csv
# Processed BAL_ohlcv.csv and saved to ../data/cleaned/ohlcv\BAL_ohlcv.csv
# Processed BAT_ohlcv.csv and saved to ../data/cleaned/ohlcv\BAT_ohlcv.csv
# Processed BCH_ohlcv.csv and saved to ../data/cleaned/ohlcv\BCH_ohlcv.csv
# Processed BEAM_ohlcv.csv and saved to ../data/cleaned/ohlcv\BEAM_ohlcv.csv
# Processed BLUR_ohlcv.csv and saved to ../data/cleaned/ohlcv\BLUR_ohlcv.csv
# Processed BNB_ohlcv.csv and saved to ../data/cleaned/ohlcv\BNB_ohlcv.csv
# Processed BNX_ohlcv.csv and saved to ../data/cleaned/ohlcv\BNX_ohlcv.csv
# Processed BOME_ohlcv.csv and saved to ../data/cleaned/ohlcv\BOME_ohlcv.csv
# Processed BRETT_ohlcv.csv and saved to ../data/cleaned/ohlcv\BRETT_ohlcv.csv
# Processed BSV_ohlcv.csv and saved to ../data/cleaned/ohlcv\BSV_ohlcv.csv
# Processed BTC_ohlcv.csv and saved to ../data/cleaned/ohlcv\BTC_ohlcv.csv
# Processed CAKE_ohlcv.csv and saved to ../data/cleaned/ohlcv\CAKE_ohlcv.csv
# Processed CELO_ohlcv.csv and saved to ../data/cleaned/ohlcv\CELO_ohlcv.csv
# Processed CFX_ohlcv.csv and saved to ../data/cleaned/ohlcv\CFX_ohlcv.csv
# Processed CHZ_ohlcv.csv and saved to ../data/cleaned/ohlcv\CHZ_ohlcv.csv
# Processed CKB_ohlcv.csv and saved to ../data/cleaned/ohlcv\CKB_ohlcv.csv
# Processed COMP_ohlcv.csv and saved to ../data/cleaned/ohlcv\COMP_ohlcv.csv
# Processed CORE_ohlcv.csv and saved to ../data/cleaned/ohlcv\CORE_ohlcv.csv
# Processed CRV_ohlcv.csv and saved to ../data/cleaned/ohlcv\CRV_ohlcv.csv
# Processed CVX_ohlcv.csv and saved to ../data/cleaned/ohlcv\CVX_ohlcv.csv
# Processed DASH_ohlcv.csv and saved to ../data/cleaned/ohlcv\DASH_ohlcv.csv
# Processed DEXE_ohlcv.csv and saved to ../data/cleaned/ohlcv\DEXE_ohlcv.csv
# Processed DOGE_ohlcv.csv and saved to ../data/cleaned/ohlcv\DOGE_ohlcv.csv
# Processed DOGS_ohlcv.csv and saved to ../data/cleaned/ohlcv\DOGS_ohlcv.csv
# Processed DOG_ohlcv.csv and saved to ../data/cleaned/ohlcv\DOG_ohlcv.csv
# Processed DOT_ohlcv.csv and saved to ../data/cleaned/ohlcv\DOT_ohlcv.csv
# Processed DYDX_ohlcv.csv and saved to ../data/cleaned/ohlcv\DYDX_ohlcv.csv
# Processed DYM_ohlcv.csv and saved to ../data/cleaned/ohlcv\DYM_ohlcv.csv
# Processed EGLD_ohlcv.csv and saved to ../data/cleaned/ohlcv\EGLD_ohlcv.csv
# Processed EIGEN_ohlcv.csv and saved to ../data/cleaned/ohlcv\EIGEN_ohlcv.csv
# Processed ENA_ohlcv.csv and saved to ../data/cleaned/ohlcv\ENA_ohlcv.csv
# Processed ENJ_ohlcv.csv and saved to ../data/cleaned/ohlcv\ENJ_ohlcv.csv
# Processed ENS_ohlcv.csv and saved to ../data/cleaned/ohlcv\ENS_ohlcv.csv
# Processed EOS_ohlcv.csv and saved to ../data/cleaned/ohlcv\EOS_ohlcv.csv
# Processed ETC_ohlcv.csv and saved to ../data/cleaned/ohlcv\ETC_ohlcv.csv
# Processed ETHW_ohlcv.csv and saved to ../data/cleaned/ohlcv\ETHW_ohlcv.csv
# Processed ETH_ohlcv.csv and saved to ../data/cleaned/ohlcv\ETH_ohlcv.csv
# Processed FET_ohlcv.csv and saved to ../data/cleaned/ohlcv\FET_ohlcv.csv
# Processed FIL_ohlcv.csv and saved to ../data/cleaned/ohlcv\FIL_ohlcv.csv
# Processed FLOW_ohlcv.csv and saved to ../data/cleaned/ohlcv\FLOW_ohlcv.csv
# Processed FLR_ohlcv.csv and saved to ../data/cleaned/ohlcv\FLR_ohlcv.csv
# Processed FTM_ohlcv.csv and saved to ../data/cleaned/ohlcv\FTM_ohlcv.csv
# Processed FTT_ohlcv.csv and saved to ../data/cleaned/ohlcv\FTT_ohlcv.csv
# Processed FXS_ohlcv.csv and saved to ../data/cleaned/ohlcv\FXS_ohlcv.csv
# Processed GALA_ohlcv.csv and saved to ../data/cleaned/ohlcv\GALA_ohlcv.csv
# Processed GAS_ohlcv.csv and saved to ../data/cleaned/ohlcv\GAS_ohlcv.csv
# Processed GLMR_ohlcv.csv and saved to ../data/cleaned/ohlcv\GLMR_ohlcv.csv
# Processed GLM_ohlcv.csv and saved to ../data/cleaned/ohlcv\GLM_ohlcv.csv
# Processed GMT_ohlcv.csv and saved to ../data/cleaned/ohlcv\GMT_ohlcv.csv
# Processed GMX_ohlcv.csv and saved to ../data/cleaned/ohlcv\GMX_ohlcv.csv
# Processed GNO_ohlcv.csv and saved to ../data/cleaned/ohlcv\GNO_ohlcv.csv
# Processed GOAT_ohlcv.csv and saved to ../data/cleaned/ohlcv\GOAT_ohlcv.csv
# Processed GRT_ohlcv.csv and saved to ../data/cleaned/ohlcv\GRT_ohlcv.csv
# Processed HBAR_ohlcv.csv and saved to ../data/cleaned/ohlcv\HBAR_ohlcv.csv
# Processed HNT_ohlcv.csv and saved to ../data/cleaned/ohlcv\HNT_ohlcv.csv
# Processed HOT_ohlcv.csv and saved to ../data/cleaned/ohlcv\HOT_ohlcv.csv
# Processed ICP_ohlcv.csv and saved to ../data/cleaned/ohlcv\ICP_ohlcv.csv
# Processed ICX_ohlcv.csv and saved to ../data/cleaned/ohlcv\ICX_ohlcv.csv
# Processed ID_ohlcv.csv and saved to ../data/cleaned/ohlcv\ID_ohlcv.csv
# Processed ILV_ohlcv.csv and saved to ../data/cleaned/ohlcv\ILV_ohlcv.csv
# Processed IMX_ohlcv.csv and saved to ../data/cleaned/ohlcv\IMX_ohlcv.csv
# Processed INJ_ohlcv.csv and saved to ../data/cleaned/ohlcv\INJ_ohlcv.csv
# Processed IOTA_ohlcv.csv and saved to ../data/cleaned/ohlcv\IOTA_ohlcv.csv
# Processed IOTX_ohlcv.csv and saved to ../data/cleaned/ohlcv\IOTX_ohlcv.csv
# Processed JASMY_ohlcv.csv and saved to ../data/cleaned/ohlcv\JASMY_ohlcv.csv
# Processed JST_ohlcv.csv and saved to ../data/cleaned/ohlcv\JST_ohlcv.csv
# Processed JUP_ohlcv.csv and saved to ../data/cleaned/ohlcv\JUP_ohlcv.csv
# Processed KAS_ohlcv.csv and saved to ../data/cleaned/ohlcv\KAS_ohlcv.csv
# Processed KAVA_ohlcv.csv and saved to ../data/cleaned/ohlcv\KAVA_ohlcv.csv
# Processed KDA_ohlcv.csv and saved to ../data/cleaned/ohlcv\KDA_ohlcv.csv
# Processed KLAY_ohlcv.csv and saved to ../data/cleaned/ohlcv\KLAY_ohlcv.csv
# Processed KSM_ohlcv.csv and saved to ../data/cleaned/ohlcv\KSM_ohlcv.csv
# Processed LDO_ohlcv.csv and saved to ../data/cleaned/ohlcv\LDO_ohlcv.csv
# Processed LINK_ohlcv.csv and saved to ../data/cleaned/ohlcv\LINK_ohlcv.csv
# Processed LOOM_ohlcv.csv and saved to ../data/cleaned/ohlcv\LOOM_ohlcv.csv
# Processed LPT_ohlcv.csv and saved to ../data/cleaned/ohlcv\LPT_ohlcv.csv
# Processed LRC_ohlcv.csv and saved to ../data/cleaned/ohlcv\LRC_ohlcv.csv
# Processed LTC_ohlcv.csv and saved to ../data/cleaned/ohlcv\LTC_ohlcv.csv
# Processed LUNA2_ohlcv.csv and saved to ../data/cleaned/ohlcv\LUNA2_ohlcv.csv
# Processed MAGIC_ohlcv.csv and saved to ../data/cleaned/ohlcv\MAGIC_ohlcv.csv
# Processed MANA_ohlcv.csv and saved to ../data/cleaned/ohlcv\MANA_ohlcv.csv
# Processed MANTA_ohlcv.csv and saved to ../data/cleaned/ohlcv\MANTA_ohlcv.csv
# Processed MASK_ohlcv.csv and saved to ../data/cleaned/ohlcv\MASK_ohlcv.csv
# Processed METIS_ohlcv.csv and saved to ../data/cleaned/ohlcv\METIS_ohlcv.csv
# Processed MEW_ohlcv.csv and saved to ../data/cleaned/ohlcv\MEW_ohlcv.csv
# Processed MINA_ohlcv.csv and saved to ../data/cleaned/ohlcv\MINA_ohlcv.csv
# Processed MKR_ohlcv.csv and saved to ../data/cleaned/ohlcv\MKR_ohlcv.csv
# Processed NEAR_ohlcv.csv and saved to ../data/cleaned/ohlcv\NEAR_ohlcv.csv
# Processed NEIRO_ohlcv.csv and saved to ../data/cleaned/ohlcv\NEIRO_ohlcv.csv
# Processed NEO_ohlcv.csv and saved to ../data/cleaned/ohlcv\NEO_ohlcv.csv
# Processed NOT_ohlcv.csv and saved to ../data/cleaned/ohlcv\NOT_ohlcv.csv
# Processed NTRN_ohlcv.csv and saved to ../data/cleaned/ohlcv\NTRN_ohlcv.csv
# Processed OCEAN_ohlcv.csv and saved to ../data/cleaned/ohlcv\OCEAN_ohlcv.csv
# Processed OMG_ohlcv.csv and saved to ../data/cleaned/ohlcv\OMG_ohlcv.csv
# Processed OM_ohlcv.csv and saved to ../data/cleaned/ohlcv\OM_ohlcv.csv
# Processed ONDO_ohlcv.csv and saved to ../data/cleaned/ohlcv\ONDO_ohlcv.csv
# Processed ONE_ohlcv.csv and saved to ../data/cleaned/ohlcv\ONE_ohlcv.csv
# Processed OP_ohlcv.csv and saved to ../data/cleaned/ohlcv\OP_ohlcv.csv
# Processed ORDI_ohlcv.csv and saved to ../data/cleaned/ohlcv\ORDI_ohlcv.csv
# Processed PENDLE_ohlcv.csv and saved to ../data/cleaned/ohlcv\PENDLE_ohlcv.csv
# Processed POL_ohlcv.csv and saved to ../data/cleaned/ohlcv\POL_ohlcv.csv
# Processed POPCAT_ohlcv.csv and saved to ../data/cleaned/ohlcv\POPCAT_ohlcv.csv
# Processed PRIME_ohlcv.csv and saved to ../data/cleaned/ohlcv\PRIME_ohlcv.csv
# Processed PYTH_ohlcv.csv and saved to ../data/cleaned/ohlcv\PYTH_ohlcv.csv
# Processed QNT_ohlcv.csv and saved to ../data/cleaned/ohlcv\QNT_ohlcv.csv
# Processed QTUM_ohlcv.csv and saved to ../data/cleaned/ohlcv\QTUM_ohlcv.csv
# Processed RAY_ohlcv.csv and saved to ../data/cleaned/ohlcv\RAY_ohlcv.csv
# Processed RENDER_ohlcv.csv and saved to ../data/cleaned/ohlcv\RENDER_ohlcv.csv
# Processed RONIN_ohlcv.csv and saved to ../data/cleaned/ohlcv\RONIN_ohlcv.csv
# Processed ROSE_ohlcv.csv and saved to ../data/cleaned/ohlcv\ROSE_ohlcv.csv
# Processed RPL_ohlcv.csv and saved to ../data/cleaned/ohlcv\RPL_ohlcv.csv
# Processed RUNE_ohlcv.csv and saved to ../data/cleaned/ohlcv\RUNE_ohlcv.csv
# Processed RVN_ohlcv.csv and saved to ../data/cleaned/ohlcv\RVN_ohlcv.csv
# Processed SAFE_ohlcv.csv and saved to ../data/cleaned/ohlcv\SAFE_ohlcv.csv
# Processed SAND_ohlcv.csv and saved to ../data/cleaned/ohlcv\SAND_ohlcv.csv
# Processed SC_ohlcv.csv and saved to ../data/cleaned/ohlcv\SC_ohlcv.csv
# Processed SEI_ohlcv.csv and saved to ../data/cleaned/ohlcv\SEI_ohlcv.csv
# Processed SFP_ohlcv.csv and saved to ../data/cleaned/ohlcv\SFP_ohlcv.csv
# Processed SNX_ohlcv.csv and saved to ../data/cleaned/ohlcv\SNX_ohlcv.csv
# Processed SOL_ohlcv.csv and saved to ../data/cleaned/ohlcv\SOL_ohlcv.csv
# Processed SSV_ohlcv.csv and saved to ../data/cleaned/ohlcv\SSV_ohlcv.csv
# Processed STORJ_ohlcv.csv and saved to ../data/cleaned/ohlcv\STORJ_ohlcv.csv
# Processed STRK_ohlcv.csv and saved to ../data/cleaned/ohlcv\STRK_ohlcv.csv
# Processed STX_ohlcv.csv and saved to ../data/cleaned/ohlcv\STX_ohlcv.csv
# Processed SUI_ohlcv.csv and saved to ../data/cleaned/ohlcv\SUI_ohlcv.csv
# Processed SUPER_ohlcv.csv and saved to ../data/cleaned/ohlcv\SUPER_ohlcv.csv
# Processed SUSHI_ohlcv.csv and saved to ../data/cleaned/ohlcv\SUSHI_ohlcv.csv
# Processed SXP_ohlcv.csv and saved to ../data/cleaned/ohlcv\SXP_ohlcv.csv
# Processed TAO_ohlcv.csv and saved to ../data/cleaned/ohlcv\TAO_ohlcv.csv
# Processed THETA_ohlcv.csv and saved to ../data/cleaned/ohlcv\THETA_ohlcv.csv
# Processed TIA_ohlcv.csv and saved to ../data/cleaned/ohlcv\TIA_ohlcv.csv
# Processed TON_ohlcv.csv and saved to ../data/cleaned/ohlcv\TON_ohlcv.csv
# Processed TRB_ohlcv.csv and saved to ../data/cleaned/ohlcv\TRB_ohlcv.csv
# Processed TRX_ohlcv.csv and saved to ../data/cleaned/ohlcv\TRX_ohlcv.csv
# Processed TWT_ohlcv.csv and saved to ../data/cleaned/ohlcv\TWT_ohlcv.csv
# Processed T_ohlcv.csv and saved to ../data/cleaned/ohlcv\T_ohlcv.csv
# Processed UNI_ohlcv.csv and saved to ../data/cleaned/ohlcv\UNI_ohlcv.csv
# Processed VET_ohlcv.csv and saved to ../data/cleaned/ohlcv\VET_ohlcv.csv
# Processed WAVES_ohlcv.csv and saved to ../data/cleaned/ohlcv\WAVES_ohlcv.csv
# Processed WIF_ohlcv.csv and saved to ../data/cleaned/ohlcv\WIF_ohlcv.csv
# Processed WLD_ohlcv.csv and saved to ../data/cleaned/ohlcv\WLD_ohlcv.csv
# Processed WOO_ohlcv.csv and saved to ../data/cleaned/ohlcv\WOO_ohlcv.csv
# Processed W_ohlcv.csv and saved to ../data/cleaned/ohlcv\W_ohlcv.csv
# Processed XCH_ohlcv.csv and saved to ../data/cleaned/ohlcv\XCH_ohlcv.csv
# Processed XEM_ohlcv.csv and saved to ../data/cleaned/ohlcv\XEM_ohlcv.csv
# Processed XLM_ohlcv.csv and saved to ../data/cleaned/ohlcv\XLM_ohlcv.csv
# Processed XMR_ohlcv.csv and saved to ../data/cleaned/ohlcv\XMR_ohlcv.csv
# Processed XRD_ohlcv.csv and saved to ../data/cleaned/ohlcv\XRD_ohlcv.csv
# Processed XRP_ohlcv.csv and saved to ../data/cleaned/ohlcv\XRP_ohlcv.csv
# Processed XTZ_ohlcv.csv and saved to ../data/cleaned/ohlcv\XTZ_ohlcv.csv
# Processed YFI_ohlcv.csv and saved to ../data/cleaned/ohlcv\YFI_ohlcv.csv
# Processed ZEC_ohlcv.csv and saved to ../data/cleaned/ohlcv\ZEC_ohlcv.csv
# Processed ZETA_ohlcv.csv and saved to ../data/cleaned/ohlcv\ZETA_ohlcv.csv
# Processed ZIL_ohlcv.csv and saved to ../data/cleaned/ohlcv\ZIL_ohlcv.csv
# Processed ZK_ohlcv.csv and saved to ../data/cleaned/ohlcv\ZK_ohlcv.csv
# Processed ZRO_ohlcv.csv and saved to ../data/cleaned/ohlcv\ZRO_ohlcv.csv
# Processed ZRX_ohlcv.csv and saved to ../data/cleaned/ohlcv\ZRX_ohlcv.csv
# TWAP calculation completed for all files.
